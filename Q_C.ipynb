# %%
import numpy as np
from qiskit.quantum_info import Statevector

theta = np.pi*np.pi/3
phi = np.pi*np.pi/8

q0 = np.cos(theta / 2)
q1 = np.exp(1j * phi) * np.sin(theta / 2)

q = Statevector([q0,q1])

# %%
q.draw('latex')
# Out:
# $$-0.0740698435 |0\rangle+(0.3298391741 + 0.9411268658 i) |1\rangle$$

# %%
q.draw('bloch')
